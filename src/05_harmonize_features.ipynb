# %%
import os
from pathlib import Path
import numpy as np
import pandas as pd
from neuroHarmonize import harmonizationLearn

# %%
## define parameters
features_dir = Path("/Volumes/Extreme_SSD/payam_data/Tide_data/features")
preproc_level = "1"
modes = ["power", "conn", "aperiodic"]
con_method = "coh"

## first read subject IDs
files = sorted(features_dir.iterdir())
files_preproc = [file for file in files if f"preproc_{preproc_level}" in file.name]
sub_ids = sorted(list(set([file.name[:9] for file in files_preproc])))

## read and sort covariates

## check for nan and matching of subject ids

## read dfs of subject IDs and create a big numpy matrix

## do harmonization + z-scoring + train on controls and apply on tinnitus

## save dfs in a new folder. "features_harmonized"

# %%
# Out:
# 121
